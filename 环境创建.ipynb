# %% [markdown]
# ### 创建个适配的环境以及安装好对应的依赖

# %% [markdown]
# 1）创建新环境以及命名

# %%
conda create -n #### python=3.10 -y
# 激活创建好的环境
conda activate ###
# 准备好依赖文件
新建一个文件：requirements.txt
#一键安装依赖包
pip install -r requirements.txt
# 检查是否安装顺利
conda env list
