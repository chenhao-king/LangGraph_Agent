# %% [markdown]
# ## ReAct Agent
# Objectives:
# 1) Learn how to create Tools in LangGraph （创建工具）
# 2) How to create a ReAct Graph  （创建一个推理+行动）reasing  and acting
# 3) work with different tpyes of messages such as ToolMessages
# 4) Teat out robustness of our graph
# Main Goal :Ceate a robust ReAct Agent! 创建一个鲁棒的推理行动模型
# ![image.png](attachment:image.png)
