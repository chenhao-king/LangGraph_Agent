# %% [markdown]
# ### Simple Bot
# Objectives:
# 1) Define state structure with a list of HumanMessage objects.（用HM对象列表定义状态结构）
# 2) Initialize a GPT-4O MODEL using LangChain 's ChatOpenAI （使用LangChain 的ChatOpenAi初始化模型）
# 3) Sending and handling different types of messages;（发送和处理不同类型的消息）
# 4) buliding and compiling the graph of the Agent（构建和编译智能体图）
# Main Goal： how to integrate LLMs in our Graphs ；（如何将LLM整合到我们的图中；）

# %%
from typing import TypedDict,List
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph,START,END
from dotenv import load_dotenv
